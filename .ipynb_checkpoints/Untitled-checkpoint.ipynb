# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('amazon_sale_data.csv', low_memory=False)

# %%
print(data)
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
print(data.head)
# Out:
# <bound method NDFrame.head of          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
print(data.info)
# Out:
# <bound method DataFrame.info of          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
data.shape
# Out:
# (128975, 24)

# %%
data.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
data.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
#saçma sütunları drop ile atıcaz
data.drop(['fulfilled-by','Unnamed: 22'],axis=1,inplace=True)

# %%
#filling(anlamlı boşluklar doldur)
data['promotion-ids'].fillna('No Promotion',inplace=True) #satır boşsa üründe promosyon uygulanmadığı anlamına gelir
data['Courier Status'].fillna('Unknown',inplace=True) #sipariş henüz kargoya verilmemiş veya iptal edilmiş olabilir
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_32504\2542362443.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['promotion-ids'].fillna('No Promotion',inplace=True) #satır boşsa üründe promosyon uygulanmadığı anlamına gelir
# C:\Users\asus\AppData\Local\Temp\ipykernel_32504\2542362443.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
#iptal edilenlerin tutarını 0 yaptım
data.loc[data['Status']== 'Cancelled','Amount']= data.loc[data['Status']=='Cancelled','Amount'].fillna(0)
data.dropna(subset=['Amount'],inplace=True)

# %%
#çok az eksik olanlara bakalım
data.dropna(subset=['ship-city','ship-state','ship-postal-code','ship-country'],inplace=True)

# %%
data.dropna(subset=['currency'])

# %%
data.isnull().sum()
# Out:
# index                    0
# Order ID                 0
# Date                     0
# Status                   0
# Fulfilment               0
# Sales Channel            0
# ship-service-level       0
# Style                    0
# SKU                      0
# Category                 0
# Size                     0
# ASIN                     0
# Courier Status           0
# Qty                      0
# currency              7564
# Amount                   0
# ship-city                0
# ship-state               0
# ship-postal-code         0
# ship-country             0
# promotion-ids            0
# B2B                      0
# dtype: int64
